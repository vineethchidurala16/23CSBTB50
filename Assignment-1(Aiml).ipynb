# %% [markdown]
# <a href="https://colab.research.google.com/github/vineethchidurala16/23CSBTB50/blob/main/Assignment-2(Aiml).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy import stats as s

# %%
d=pd.read_excel("/content/Book-1(52447).xlsx")
d
# Out:
#      SID       S.Name Course  Age   Contact No.
# 0   2111        Arnav    CSE   19    9563254787
# 1   2112        Pavan    CSE   19    9423236589
# 2   2113       Rajesh   AIML   19    7569692316
# 3   2114   Vishwateja   AIML   20    8315154325
# 4   2115      Avinash   AIML   19    9848195425
# 5   2116        Vivek   AIML   19    9832363512
# 6   2117   Ram Charan    CSE   19    8957572315
# 7   2118     Sai teja    CSE   19    9848563631
# 8   2119      Karthik    CSE   19    7852521613
# 9   2120      Pradeep    CSE   19    8562621546
# 10  2121    Abhimanyu    CSE   19    7395216231
# 11  2122        Rahul    ECE   19    7852691321
# 12  2123       Naveen    ECE   20    9642334973
# 13  2124         Hari    ECE   19    7394332964
# 14  2125        Arjun    CSE   19    7330361524
# 15  2126        Ayush   AIML   19    7416258966
# 16  2127  Sri vasthav   AIML   19    9656485761
# 17  2128       Akhil    AIML   19    9254652315
# 18  2129         Ajay   AIML   20    6523154162
# ...

# %%
a=pd.read_csv("/content/heart.csv")
a
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
b=pd.read_csv("/content/games_dataset.csv")
b
# Out:
#                                     Game Name       Genre         Platform  \
# 0                   Sekiro: Shadows Die Twice      Sports  Nintendo Switch
# 1                                     Control      Puzzle  Nintendo Switch
# 2                                    Among Us    Strategy  Nintendo Switch
# 3                Call of Duty: Modern Warfare     Stealth      PlayStation
# 4                           League of Legends  Simulation               PC
# ...                                       ...         ...              ...
# 4995  The Legend of Zelda: Breath of the Wild      Sports               PC
# 4996                Assassin's Creed Valhalla     Stealth           Mobile
# 4997             Fall Guys: Ultimate Knockout      Sports           Mobile
# 4998                            Borderlands 3  Platformer             Xbox
# 4999         Counter-Strike: Global Offensive      Action      PlayStation
#
#       Release Year  User Rating
# 0             2014     9.654719
# ...
